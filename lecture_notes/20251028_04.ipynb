# %% [markdown]
# # 28.10.2025 - Lecture 04
#
# <img src="Figures/04_01_grenzen.svg" width=400em/>
#
# 1. Umgebung (Grenzen (blau))
# 1. Start + Ziel
# 1. Grenzen
#
# Ergebnis <--> Bewertung
# - Zeit Berechnung
# - Länge Weg
# - Anzahl Knoten
# - Szenen
# - Kollisionstests ?
# - Erfolg ?
